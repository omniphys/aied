# %% [markdown]
# <a href="https://colab.research.google.com/github/omniphys/aied/blob/main/01_Perceptron.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **인공지능, 머신러닝, 딥러닝![ai-neuralnetworks.png](data:image/png;base64,...)**
